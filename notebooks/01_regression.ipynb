# %% [markdown]
# # Regresión lineal
#
# ## Objetivo
# Predecir una variable continua a partir de variables explicativas.
#
# ## Dataset
# Dataset sintético generado para validar el modelo.
#
# ## Variables
# - X: variable explicativa
# - y: variable objetivo
#
# ## Modelo
# Regresión lineal ordinaria (OLS).
#
# ## Métrica
# - RMSE
# - MAE
#
# ## Desarrollo
# Implementación usando scikit-learn.
#
# ## Resultados
# (Completar luego)
#
# ## Interpretación
# (Completar luego)
#
# ## Conclusión
# (Completar luego)

# %% [markdown]
# python3 -m venv .venv
# source .venv/bin/activate
# pip install jupyter ipykernel

# %%
import numpy as np
import pandas as pd

print("todo funciona")
# Out:
# todo funciona
